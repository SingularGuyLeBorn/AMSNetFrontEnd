# %%
import os
from pathlib import Path
from typing import List, Set, Optional


#将文件夹下的所有代码合并输出
def concatenate_files_with_separator(
    root_directory: str,
    output_filepath: str,
    target_extensions: List[str],
    excluded_folders: Optional[Set[str]] = None
) -> None:
    """
    读取目录下指定扩展名的文件内容，并使用路径/文件名作为分隔符，
    将它们拼接到一个输出 TXT 文件中。支持排除某些文件夹。

    Args:
        root_directory (str): 要搜索的根目录路径。
        output_filepath (str): 输出 TXT 文件的路径。
        target_extensions (List[str]): 要读取的文件扩展名列表 (例如: ['.txt', '.py'])。
                                       确保扩展名以 '.' 开头。
        excluded_folders (Optional[Set[str]]): 要排除的文件夹名称集合 (例如: {'__pycache__', '.venv'})。
                                               这些文件夹及其子文件夹下的文件将被忽略。
                                               默认为 None (不排除任何文件夹)。
    """
    if excluded_folders is None:
        excluded_folders = set()

    root_path = Path(root_directory).resolve()
    output_file = Path(output_filepath).resolve()

    if not root_path.is_dir():
        print(f"错误: 根目录 '{root_directory}' 不存在或不是一个目录。")
        return

    # 确保目标扩展名以 '.' 开头
    processed_extensions = [ext if ext.startswith('.') else f".{ext}" for ext in target_extensions]
    if not processed_extensions:
        print("错误: 必须提供至少一个目标文件扩展名。")
        return

    print(f"开始处理目录: {root_path}")
    print(f"输出文件: {output_file}")
    print(f"目标扩展名: {processed_extensions}")
    print(f"排除的文件夹: {excluded_folders if excluded_folders else '无'}")

    file_count = 0
    with open(output_file, 'w', encoding='utf-8') as outfile:
        for dirpath_str, dirnames, filenames in os.walk(root_path, topdown=True):
            current_dir_path = Path(dirpath_str)

            # 排除文件夹：修改 dirnames 列表以阻止 os.walk 进入这些目录
            # 这是 os.walk 的一个特性，在 topdown=True 时有效
            dirnames[:] = [d for d in dirnames if d not in excluded_folders]

            # 检查当前目录本身是否在排除列表中（这主要针对根目录直接是排除目录的情况，
            # 或者 excluded_folders 包含像 'src/tests' 这样的相对路径，但我们这里用的是文件夹名）
            # 对于简单的文件夹名排除，上面的 dirnames[:] 修改已经足够了。
            # 如果 current_dir_path.name 在 excluded_folders 中，我们就不应该处理这个目录中的文件
            # 但由于上面修改了 dirnames，os.walk 不会再进入这些目录的子目录。
            # 我们只需要确保不处理当前这个被排除目录下的文件。
            if current_dir_path.name in excluded_folders and current_dir_path != root_path:
                 print(f"  跳过排除的文件夹中的文件: {current_dir_path}")
                 continue


            for filename in filenames:
                file_path = current_dir_path / filename
                if file_path.suffix.lower() in processed_extensions:
                    relative_path = file_path.relative_to(root_path)
                    # 使用 POSIX 风格的路径分隔符 '/' 以保持一致性
                    separator = f"--- START: {relative_path.as_posix()} ---"
                    end_separator = f"--- END: {relative_path.as_posix()} ---\n\n"

                    outfile.write(separator + "\n")
                    try:
                        with open(file_path, 'r', encoding='utf-8', errors='ignore') as infile:
                            outfile.write(infile.read())
                        outfile.write("\n" + end_separator) # 在文件内容后加换行，然后是结束分隔符
                        file_count += 1
                        print(f"  已处理: {relative_path.as_posix()}")
                    except Exception as e:
                        error_message = f"无法读取文件 '{file_path.as_posix()}': {e}"
                        outfile.write(f"[错误: {error_message}]\n")
                        outfile.write(end_separator)
                        print(f"  错误: {error_message}")

    if file_count > 0:
        print(f"\n处理完成！{file_count} 个文件的内容已拼接到 '{output_file.as_posix()}'。")
    else:
        print(f"\n处理完成。在 '{root_path.as_posix()}' 中未找到指定扩展名的文件 (或均在排除文件夹内)。")
        if not output_file.exists() or output_file.stat().st_size == 0 :
             print(f"输出文件 '{output_file.as_posix()}' 为空或未创建。")


if __name__ == '__main__':
    # ----- 配置参数 -----
    # 1. 要搜索的根目录
    source_directory = "D:\东方理工\AMSNet\AMSNetFrontEnd"

    # 2. 输出的 TXT 文件名和路径
    concatenated_output_file = "completeCode.txt"

    # 3. 要包含的文件扩展名 (例如: '.txt', '.py', '.md')
    include_extensions = ['.tsx', '.ts', 'html','css']  # 请根据需要修改

    # 4. 要排除的文件夹名称 (例如: '__pycache__', 'node_modules', '.git')
    #    这些文件夹及其所有子文件夹下的文件都将被忽略。
    folders_to_exclude: Set[str] = {'__pycache__', '.venv', 'node_modules', '.git', 'dist', 'build', '__pycache__', 'WebUIAgentLogs'}
    # folders_to_exclude = None # 如果不想排除任何文件夹

    concatenate_files_with_separator(
        root_directory=source_directory,
        output_filepath=concatenated_output_file,
        target_extensions=include_extensions,
        excluded_folders=folders_to_exclude
    )

    # 简单的验证输出文件内容
    output_p = Path(concatenated_output_file)
    if output_p.exists() and output_p.stat().st_size > 0:
        print(f"\n--- '{concatenated_output_file}' 的前200个字符 ---")
        with open(output_p, 'r', encoding='utf-8') as f:
            print(f.read(200) + "...")
        print("--- END ---")
    elif output_p.exists():
        print(f"\n--- '{concatenated_output_file}' 是空的 ---")
# Out:
# 开始处理目录: D:\东方理工\AMSNet\AMSNetFrontEnd
# 输出文件: completeCode.txt
# 目标扩展名: ['.tsx', '.ts', '.html', '.css']
# 排除的文件夹: {'__pycache__', '.git', 'build', '.venv', 'WebUIAgentLogs', 'node_modules', 'dist'}
#   已处理: config/config.ts
#   已处理: config/defaultSettings.ts
#   已处理: config/proxy.ts
#   已处理: config/routes.ts
#   已处理: html/529.4e8e488f.chunk.css
#   已处理: html/index.html
#   已处理: html/p__FileOperate__index.76e6d84f.chunk.css
#   已处理: html/p__GraphOperate__index.063168a2.chunk.css
#   已处理: html/p__MaskOperate__index.571aa929.chunk.css
#   已处理: html/p__Welcome.d90849c7.chunk.css
#   已处理: html/t__plugin-layout__Layout.5012e1ab.chunk.css
#   已处理: html/umi.fe20e75b.css
#   已处理: src/access.ts
#   已处理: src/app.tsx
#   已处理: src/global.tsx
#   已处理: src/requestConfig.ts
#   已处理: src/typings.d.ts
#   已处理: src/.umi/exports.ts
#   已处理: src/.umi/testBrowser.tsx
#   已处理: src/.umi/typings.d.ts
#   已处理: src/.umi/umi.ts
#   已处理: src/.umi/core/defineApp.ts
#   已处理: src/.umi/core/EmptyRoute.tsx
#   已处理: src/.umi/core/helmet.ts
#   已处理: src/.umi/core/helmetContext.ts
#   已处理: src/.umi/core/history.ts
#   已处理: src/.umi/core/historyIntelli.ts
#   已处理: src/.umi/core/plugin.ts
#   已处理: src/.umi/core/pluginConfig.ts
#   已处理: src/.umi/core/pluginConfigJoi.d.ts
#   已处理: src/.umi/core/polyfill.ts
#   已处理: src/.umi/core/route.tsx
#   已处理: src/.umi/core/terminal.ts
#   已处理: src/.umi/plugin-access/context.ts
#   已处理: src/.umi/plugin-access/index.tsx
#   已处理: src/.umi/plugin-access/runtime.tsx
#   已处理: src/.umi/plugin-access/types.d.ts
#   已处理: src/.umi/plugin-antd/runtime.tsx
#   已处理: src/.umi/plugin-antd/runtimeConfig.d.ts
#   已处理: src/.umi/plugin-antd/types.d.ts
#   已处理: src/.umi/plugin-initialState/@@initialState.ts
#   已处理: src/.umi/plugin-initialState/Provider.tsx
#   已处理: src/.umi/plugin-initialState/runtime.tsx
#   已处理: src/.umi/plugin-initialState/runtimeConfig.d.ts
#   已处理: src/.umi/plugin-layout/Exception.tsx
#   已处理: src/.umi/plugin-layout/icons.tsx
#   已处理: src/.umi/plugin-layout/index.ts
#   已处理: src/.umi/plugin-layout/Layout.css
#   已处理: src/.umi/plugin-layout/Layout.tsx
#   已处理: src/.umi/plugin-layout/Logo.tsx
#   已处理: src/.umi/plugin-layout/rightRender.tsx
#   已处理: src/.umi/plugin-layout/runtime.tsx
#   已处理: src/.umi/plugin-layout/runtimeConfig.d.ts
#   已处理: src/.umi/plugin-layout/types.d.ts
#   已处理: src/.umi/plugin-model/index.tsx
#   已处理: src/.umi/plugin-model/model.ts
#   已处理: src/.umi/plugin-model/runtime.tsx
#   已处理: src/.umi/plugin-moment2dayjs/runtime.tsx
#   已处理: src/.umi/plugin-openapi/openapi.tsx
#   已处理: src/.umi/plugin-request/index.ts
#   已处理: src/.umi/plugin-request/request.ts
#   已处理: src/.umi/plugin-request/runtimeConfig.d.ts
#   已处理: src/.umi/plugin-request/types.d.ts
#   已处理: src/.umi-production/exports.ts
#   已处理: src/.umi-production/testBrowser.tsx
#   已处理: src/.umi-production/typings.d.ts
#   已处理: src/.umi-production/umi.ts
#   已处理: src/.umi-production/core/defineApp.ts
#   已处理: src/.umi-production/core/EmptyRoute.tsx
#   已处理: src/.umi-production/core/helmet.ts
#   已处理: src/.umi-production/core/helmetContext.ts
#   已处理: src/.umi-production/core/history.ts
#   已处理: src/.umi-production/core/historyIntelli.ts
#   已处理: src/.umi-production/core/plugin.ts
#   已处理: src/.umi-production/core/pluginConfig.ts
#   已处理: src/.umi-production/core/pluginConfigJoi.d.ts
#   已处理: src/.umi-production/core/polyfill.ts
#   已处理: src/.umi-production/core/route.tsx
#   已处理: src/.umi-production/core/terminal.ts
#   已处理: src/.umi-production/plugin-access/context.ts
#   已处理: src/.umi-production/plugin-access/index.tsx
#   已处理: src/.umi-production/plugin-access/runtime.tsx
#   已处理: src/.umi-production/plugin-access/types.d.ts
#   已处理: src/.umi-production/plugin-antd/runtime.tsx
#   已处理: src/.umi-production/plugin-antd/runtimeConfig.d.ts
#   已处理: src/.umi-production/plugin-antd/types.d.ts
#   已处理: src/.umi-production/plugin-initialState/@@initialState.ts
#   已处理: src/.umi-production/plugin-initialState/Provider.tsx
#   已处理: src/.umi-production/plugin-initialState/runtime.tsx
#   已处理: src/.umi-production/plugin-initialState/runtimeConfig.d.ts
#   已处理: src/.umi-production/plugin-layout/Exception.tsx
#   已处理: src/.umi-production/plugin-layout/icons.tsx
#   已处理: src/.umi-production/plugin-layout/index.ts
#   已处理: src/.umi-production/plugin-layout/Layout.css
#   已处理: src/.umi-production/plugin-layout/Layout.tsx
#   已处理: src/.umi-production/plugin-layout/Logo.tsx
#   已处理: src/.umi-production/plugin-layout/rightRender.tsx
#   已处理: src/.umi-production/plugin-layout/runtime.tsx
#   已处理: src/.umi-production/plugin-layout/runtimeConfig.d.ts
#   已处理: src/.umi-production/plugin-layout/types.d.ts
#   已处理: src/.umi-production/plugin-model/index.tsx
#   已处理: src/.umi-production/plugin-model/model.ts
#   已处理: src/.umi-production/plugin-model/runtime.tsx
#   已处理: src/.umi-production/plugin-moment2dayjs/runtime.tsx
#   已处理: src/.umi-production/plugin-request/index.ts
#   已处理: src/.umi-production/plugin-request/request.ts
#   已处理: src/.umi-production/plugin-request/runtimeConfig.d.ts
#   已处理: src/.umi-production/plugin-request/types.d.ts
#   已处理: src/components/Footer/index.tsx
#   已处理: src/components/HeaderDropdown/index.tsx
#   已处理: src/components/RightContent/AvatarDropdown.tsx
#   已处理: src/constants/index.ts
#   已处理: src/pages/404.tsx
#   已处理: src/pages/Admin.tsx
#   已处理: src/pages/Welcome.css
#   已处理: src/pages/Welcome.tsx
#   已处理: src/pages/Admin/User/index.tsx
#   已处理: src/pages/Admin/User/components/CreateModal.tsx
#   已处理: src/pages/Admin/User/components/UpdateModal.tsx
#   已处理: src/pages/FileOperate/index.css
#   已处理: src/pages/FileOperate/index.tsx
#   已处理: src/pages/FloatWindow/float-window.css
#   已处理: src/pages/FloatWindow/index.tsx
#   已处理: src/pages/GraphOperate/index.css
#   已处理: src/pages/GraphOperate/index.tsx
#   已处理: src/pages/GraphOperate/Components/apiFunctions.tsx
#   已处理: src/pages/GraphOperate/Components/Neo4jVisualization.tsx
#   已处理: src/pages/GraphOperate/Constants/dataTypes.ts
#   已处理: src/pages/GraphOperate/Styles/Button.css
#   已处理: src/pages/GraphOperate/Styles/customStyles.css
#   已处理: src/pages/MaskOperate/index.css
#   已处理: src/pages/MaskOperate/index.tsx
#   已处理: src/pages/MaskOperate-Test/index.tsx
#   已处理: src/pages/MaskOperate-Test/Styles/MaskOperate.css
#   已处理: src/pages/User/Login/index.tsx
#   已处理: src/pages/User/Register/index.tsx
#   已处理: src/pages/welcome(unuse)/Welcome.css
#   已处理: src/pages/welcome(unuse)/Welcome.tsx
#   已处理: src/services/backend/fileController.ts
#   已处理: src/services/backend/graphController.ts
#   已处理: src/services/backend/index.ts
#   已处理: src/services/backend/postController.ts
#   已处理: src/services/backend/postFavourController.ts
#   已处理: src/services/backend/postThumbController.ts
#   已处理: src/services/backend/typings.d.ts
#   已处理: src/services/backend/userController.ts
#   已处理: src/services/backend/wxMpController.ts
#
# 处理完成！147 个文件的内容已拼接到 'completeCode.txt'。
#
# --- 'completeCode.txt' 的前200个字符 ---
# --- START: config/config.ts ---
# // https://umijs.org/config/
# import { defineConfig } from '@umijs/max';
# import { join } from 'path';
# import defaultSettings from './defaultSettings';
# import proxy from ...
# --- END ---
